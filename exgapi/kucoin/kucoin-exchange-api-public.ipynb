# %% [markdown]
# # Import library
# Run pip install xxx if a package is not installed on your computer

# %%
import requests
import json
import time
import hashlib
import hmac
import base64

# %% [markdown]
# # Global variables

# %%
kchost = "https://api.kucoin.com"

# %% [markdown]
# # Util functions

# %%
def getPublic(endpoint):
    url = "%s%s" % (kchost, endpoint)
    return requests.get(url, timeout=5).json()

# %%
def paramURL(params):
    items = params.items()
    t = ["%s=%s" % (k, v) for k, v in items]
    return "&".join(t)
def getPublic(endpoint, params):
    parmurl = paramURL(params)
    if len(parmurl) > 0:
        parmurl = "?" + parmurl
    url = "%s%s%s" % (kchost, endpoint, parmurl)
    return requests.get(url, timeout=5).json()

# %% [markdown]
# # Public API endpoints

# %% [markdown]
# ## list of trading symbols

# %%
endpoint = "/api/v1/symbols"
symbols = getPublic(endpoint)

# %%
symbols
# Out:
# {'code': '200000',
#  'data': [{'symbol': 'REQ-ETH',
#    'name': 'REQ-ETH',
#    'baseCurrency': 'REQ',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'REQ-BTC',
#    'name': 'REQ-BTC',
#    'baseCurrency': 'REQ',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NULS-ETH',
#    'name': 'NULS-ETH',
#    'baseCurrency': 'NULS',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NULS-BTC',
#    'name': 'NULS-BTC',
#    'baseCurrency': 'NULS',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CVC-BTC',
#    'name': 'CVC-BTC',
#    'baseCurrency': 'CVC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SNT-ETH',
#    'name': 'SNT-ETH',
#    'baseCurrency': 'SNT',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SNT-BTC',
#    'name': 'SNT-BTC',
#    'baseCurrency': 'SNT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'PPT-ETH',
#    'name': 'PPT-ETH',
#    'baseCurrency': 'PPT',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'PPT-BTC',
#    'name': 'PPT-BTC',
#    'baseCurrency': 'PPT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BCHSV-BTC',
#    'name': 'BSV-BTC',
#    'baseCurrency': 'BSV',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'POWR-BTC',
#    'name': 'POWR-BTC',
#    'baseCurrency': 'POWR',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'POWR-ETH',
#    'name': 'POWR-ETH',
#    'baseCurrency': 'POWR',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BCD-BTC',
#    'name': 'BCD-BTC',
#    'baseCurrency': 'BCD',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BCD-ETH',
#    'name': 'BCD-ETH',
#    'baseCurrency': 'BCD',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'KNC-ETH',
#    'name': 'KNC-ETH',
#    'baseCurrency': 'KNC',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'DeFi',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'KNC-BTC',
#    'name': 'KNC-BTC',
#    'baseCurrency': 'KNC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'DeFi',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'OMG-ETH',
#    'name': 'OMG-ETH',
#    'baseCurrency': 'OMG',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'OMG-BTC',
#    'name': 'OMG-BTC',
#    'baseCurrency': 'OMG',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'CHSB-BTC',
#    'name': 'CHSB-BTC',
#    'baseCurrency': 'CHSB',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CHSB-ETH',
#    'name': 'CHSB-ETH',
#    'baseCurrency': 'CHSB',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MANA-BTC',
#    'name': 'MANA-BTC',
#    'baseCurrency': 'MANA',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'NFT',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AMB-ETH',
#    'name': 'AMB-ETH',
#    'baseCurrency': 'AMB',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MANA-ETH',
#    'name': 'MANA-ETH',
#    'baseCurrency': 'MANA',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'NFT',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AMB-BTC',
#    'name': 'AMB-BTC',
#    'baseCurrency': 'AMB',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ETN-BTC',
#    'name': 'ETN-BTC',
#    'baseCurrency': 'ETN',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DGB-BTC',
#    'name': 'DGB-BTC',
#    'baseCurrency': 'DGB',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DGB-ETH',
#    'name': 'DGB-ETH',
#    'baseCurrency': 'DGB',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'QTUM-BTC',
#    'name': 'QTUM-BTC',
#    'baseCurrency': 'QTUM',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AION-ETH',
#    'name': 'AION-ETH',
#    'baseCurrency': 'AION',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AION-BTC',
#    'name': 'AION-BTC',
#    'baseCurrency': 'AION',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'WTC-BTC',
#    'name': 'WTC-BTC',
#    'baseCurrency': 'WTC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ENJ-BTC',
#    'name': 'ENJ-BTC',
#    'baseCurrency': 'ENJ',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'NFT',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ENJ-ETH',
#    'name': 'ENJ-ETH',
#    'baseCurrency': 'ENJ',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'NFT',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SNX-ETH',
#    'name': 'SNX-ETH',
#    'baseCurrency': 'SNX',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'DeFi',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TIME-ETH',
#    'name': 'TIME-ETH',
#    'baseCurrency': 'TIME',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SNX-USDT',
#    'name': 'SNX-USDT',
#    'baseCurrency': 'SNX',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'DeFi',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'SNX-BTC',
#    'name': 'SNX-BTC',
#    'baseCurrency': 'SNX',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'DeFi',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TIME-BTC',
#    'name': 'TIME-BTC',
#    'baseCurrency': 'TIME',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'XLM-USDT',
#    'name': 'XLM-USDT',
#    'baseCurrency': 'XLM',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'VET-USDT',
#    'name': 'VET-USDT',
#    'baseCurrency': 'VET',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'DASH-ETH',
#    'name': 'DASH-ETH',
#    'baseCurrency': 'DASH',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.0001',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.00001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'UTK-BTC',
#    'name': 'UTK-BTC',
#    'baseCurrency': 'UTK',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'UTK-ETH',
#    'name': 'UTK-ETH',
#    'baseCurrency': 'UTK',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DASH-BTC',
#    'name': 'DASH-BTC',
#    'baseCurrency': 'DASH',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.0001',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.00000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'GO-USDT',
#    'name': 'GO-USDT',
#    'baseCurrency': 'GO',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AXPR-ETH',
#    'name': 'AXPR-ETH',
#    'baseCurrency': 'AXPR',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AXPR-BTC',
#    'name': 'AXPR-BTC',
#    'baseCurrency': 'AXPR',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ACT-ETH',
#    'name': 'ACT-ETH',
#    'baseCurrency': 'ACT',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ACT-BTC',
#    'name': 'ACT-BTC',
#    'baseCurrency': 'ACT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'EOS-KCS',
#    'name': 'EOS-KCS',
#    'baseCurrency': 'EOS',
#    'quoteCurrency': 'KCS',
#    'feeCurrency': 'KCS',
#    'market': 'KCS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ETC-ETH',
#    'name': 'ETC-ETH',
#    'baseCurrency': 'ETC',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'EOS-BTC',
#    'name': 'EOS-BTC',
#    'baseCurrency': 'EOS',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'PLAY-BTC',
#    'name': 'PLAY-BTC',
#    'baseCurrency': 'PLAY',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ETC-BTC',
#    'name': 'ETC-BTC',
#    'baseCurrency': 'ETC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'EOS-USDT',
#    'name': 'EOS-USDT',
#    'baseCurrency': 'EOS',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'EOS-ETH',
#    'name': 'EOS-ETH',
#    'baseCurrency': 'EOS',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'GAS-BTC',
#    'name': 'GAS-BTC',
#    'baseCurrency': 'GAS',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BCH-BTC',
#    'name': 'BCH-BTC',
#    'baseCurrency': 'BCH',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.0001',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'PLAY-ETH',
#    'name': 'PLAY-ETH',
#    'baseCurrency': 'PLAY',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ETC-USDT',
#    'name': 'ETC-USDT',
#    'baseCurrency': 'ETC',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'DENT-ETH',
#    'name': 'DENT-ETH',
#    'baseCurrency': 'DENT',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DENT-BTC',
#    'name': 'DENT-BTC',
#    'baseCurrency': 'DENT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DRGN-BTC',
#    'name': 'DRGN-BTC',
#    'baseCurrency': 'DRGN',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DRGN-ETH',
#    'name': 'DRGN-ETH',
#    'baseCurrency': 'DRGN',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LTC-USDT',
#    'name': 'LTC-USDT',
#    'baseCurrency': 'LTC',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'CV-BTC',
#    'name': 'CV-BTC',
#    'baseCurrency': 'CV',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LTC-ETH',
#    'name': 'LTC-ETH',
#    'baseCurrency': 'LTC',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.00001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'CV-ETH',
#    'name': 'CV-ETH',
#    'baseCurrency': 'CV',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LTC-BTC',
#    'name': 'LTC-BTC',
#    'baseCurrency': 'LTC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'KEY-BTC',
#    'name': 'KEY-BTC',
#    'baseCurrency': 'KEY',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'KEY-ETH',
#    'name': 'KEY-ETH',
#    'baseCurrency': 'KEY',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'IOST-ETH',
#    'name': 'IOST-ETH',
#    'baseCurrency': 'IOST',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ADB-ETH',
#    'name': 'ADB-ETH',
#    'baseCurrency': 'ADB',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ADB-BTC',
#    'name': 'ADB-BTC',
#    'baseCurrency': 'ADB',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'IOST-BTC',
#    'name': 'IOST-BTC',
#    'baseCurrency': 'IOST',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'TEL-BTC',
#    'name': 'TEL-BTC',
#    'baseCurrency': 'TEL',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CXO-BTC',
#    'name': 'CXO-BTC',
#    'baseCurrency': 'CXO',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'WAX-BTC',
#    'name': 'WAXP-BTC',
#    'baseCurrency': 'WAXP',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TEL-ETH',
#    'name': 'TEL-ETH',
#    'baseCurrency': 'TEL',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'WAX-ETH',
#    'name': 'WAXP-ETH',
#    'baseCurrency': 'WAXP',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CXO-ETH',
#    'name': 'CXO-ETH',
#    'baseCurrency': 'CXO',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CAPP-ETH',
#    'name': 'CAPP-ETH',
#    'baseCurrency': 'CAPP',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NANO-USDT',
#    'name': 'NANO-USDT',
#    'baseCurrency': 'NANO',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.000001',
#    'priceIncrement': '0.000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TKY-BTC',
#    'name': 'TKY-BTC',
#    'baseCurrency': 'TKY',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CAPP-BTC',
#    'name': 'CAPP-BTC',
#    'baseCurrency': 'CAPP',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.01',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NANO-BTC',
#    'name': 'NANO-BTC',
#    'baseCurrency': 'NANO',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NANO-ETH',
#    'name': 'NANO-ETH',
#    'baseCurrency': 'NANO',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TKY-ETH',
#    'name': 'TKY-ETH',
#    'baseCurrency': 'TKY',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ELF-ETH',
#    'name': 'ELF-ETH',
#    'baseCurrency': 'ELF',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'COV-ETH',
#    'name': 'COV-ETH',
#    'baseCurrency': 'COV',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ZIL-BTC',
#    'name': 'ZIL-BTC',
#    'baseCurrency': 'ZIL',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'ELF-BTC',
#    'name': 'ELF-BTC',
#    'baseCurrency': 'ELF',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LTC-KCS',
#    'name': 'LTC-KCS',
#    'baseCurrency': 'LTC',
#    'quoteCurrency': 'KCS',
#    'feeCurrency': 'KCS',
#    'market': 'KCS',
#    'baseMinSize': '0.001',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.000001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MAN-BTC',
#    'name': 'MAN-BTC',
#    'baseCurrency': 'MAN',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'COV-BTC',
#    'name': 'COV-BTC',
#    'baseCurrency': 'COV',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ZIL-ETH',
#    'name': 'ZIL-ETH',
#    'baseCurrency': 'ZIL',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TOMO-ETH',
#    'name': 'TOMO-ETH',
#    'baseCurrency': 'TOMO',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ONT-BTC',
#    'name': 'ONT-BTC',
#    'baseCurrency': 'ONT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'GO-BTC',
#    'name': 'GO-BTC',
#    'baseCurrency': 'GO',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TOMO-BTC',
#    'name': 'TOMO-BTC',
#    'baseCurrency': 'TOMO',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BAX-ETH',
#    'name': 'BAX-ETH',
#    'baseCurrency': 'BAX',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '100',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LYM-ETH',
#    'name': 'LYM-ETH',
#    'baseCurrency': 'LYM',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TRAC-ETH',
#    'name': 'TRAC-ETH',
#    'baseCurrency': 'TRAC',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'IOTX-ETH',
#    'name': 'IOTX-ETH',
#    'baseCurrency': 'IOTX',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SOUL-BTC',
#    'name': 'SOUL-BTC',
#    'baseCurrency': 'SOUL',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'NFT',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ONT-ETH',
#    'name': 'ONT-ETH',
#    'baseCurrency': 'ONT',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LOOM-ETH',
#    'name': 'LOOM-ETH',
#    'baseCurrency': 'LOOM',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TRAC-BTC',
#    'name': 'TRAC-BTC',
#    'baseCurrency': 'TRAC',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
# ...
#    'name': 'LRC-ETH',
#    'baseCurrency': 'LRC',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'DPR-USDT',
#    'name': 'DPR-USDT',
#    'baseCurrency': 'DPR',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CWAR-USDT',
#    'name': 'CWAR-USDT',
#    'baseCurrency': 'CWAR',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'CWAR-BTC',
#    'name': 'CWAR-BTC',
#    'baseCurrency': 'CWAR',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'FLUX-BTC',
#    'name': 'FLUX-BTC',
#    'baseCurrency': 'FLUX',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'EDG-BTC',
#    'name': 'EDG-BTC',
#    'baseCurrency': 'EDG',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.0000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000000001',
#    'priceIncrement': '0.0000000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'PBR-USDT',
#    'name': 'PBR-USDT',
#    'baseCurrency': 'PBR',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'WNXM-USDT',
#    'name': 'WNXM-USDT',
#    'baseCurrency': 'WNXM',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.001',
#    'priceIncrement': '0.001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'WNXM-BTC',
#    'name': 'WNXM-BTC',
#    'baseCurrency': 'WNXM',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.01',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ANT-USDT',
#    'name': 'ANT-USDT',
#    'baseCurrency': 'ANT',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': True,
#    'enableTrading': True},
#   {'symbol': 'ANT-BTC',
#    'name': 'ANT-BTC',
#    'baseCurrency': 'ANT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'COV-USDT',
#    'name': 'COV-USDT',
#    'baseCurrency': 'COV',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'SWP-USDT',
#    'name': 'SWP-USDT',
#    'baseCurrency': 'SWP',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TWT-USDT',
#    'name': 'TWT-USDT',
#    'baseCurrency': 'TWT',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TWT-BTC',
#    'name': 'TWT-BTC',
#    'baseCurrency': 'TWT',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'OM-USDT',
#    'name': 'OM-USDT',
#    'baseCurrency': 'OM',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'OM-BTC',
#    'name': 'OM-BTC',
#    'baseCurrency': 'OM',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'ADX-USDT',
#    'name': 'ADX-USDT',
#    'baseCurrency': 'ADX',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AVAX3L-USDT',
#    'name': 'AVAX3L-USDT',
#    'baseCurrency': 'AVAX3L',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '999999999999999',
#    'quoteMaxSize': '10000',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'AVAX3S-USDT',
#    'name': 'AVAX3S-USDT',
#    'baseCurrency': 'AVAX3S',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '99999999999999',
#    'quoteMaxSize': '10000',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MANA3L-USDT',
#    'name': 'MANA3L-USDT',
#    'baseCurrency': 'MANA3L',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '99999999999',
#    'quoteMaxSize': '5000',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MANA3S-USDT',
#    'name': 'MANA3S-USDT',
#    'baseCurrency': 'MANA3S',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '9999999999999',
#    'quoteMaxSize': '5000',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'GLM-USDT',
#    'name': 'GLM-USDT',
#    'baseCurrency': 'GLM',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'GLM-BTC',
#    'name': 'GLM-BTC',
#    'baseCurrency': 'GLM',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BAKE-USDT',
#    'name': 'BAKE-USDT',
#    'baseCurrency': 'BAKE',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BAKE-BTC',
#    'name': 'BAKE-BTC',
#    'baseCurrency': 'BAKE',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'BAKE-ETH',
#    'name': 'BAKE-ETH',
#    'baseCurrency': 'BAKE',
#    'quoteCurrency': 'ETH',
#    'feeCurrency': 'ETH',
#    'market': 'ALTS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.00001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0000001',
#    'priceIncrement': '0.0000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'NUM-USDT',
#    'name': 'NUM-USDT',
#    'baseCurrency': 'NUM',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.01',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'VLX-USDT',
#    'name': 'VLX-USDT',
#    'baseCurrency': 'VLX',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'VLX-BTC',
#    'name': 'VLX-BTC',
#    'baseCurrency': 'VLX',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TRADE-USDT',
#    'name': 'TRADE-USDT',
#    'baseCurrency': 'TRADE',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'TRADE-BTC',
#    'name': 'TRADE-BTC',
#    'baseCurrency': 'TRADE',
#    'quoteCurrency': 'BTC',
#    'feeCurrency': 'BTC',
#    'market': 'BTC',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.000001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00000001',
#    'priceIncrement': '0.00000001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': '1EARTH-USDT',
#    'name': '1EARTH-USDT',
#    'baseCurrency': '1EARTH',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'DeFi',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MONI-USDT',
#    'name': 'MONI-USDT',
#    'baseCurrency': 'MONI',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '0.1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'LIKE-USDT',
#    'name': 'LIKE-USDT',
#    'baseCurrency': 'LIKE',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '1',
#    'quoteMinSize': '0.1',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.0001',
#    'priceIncrement': '0.0001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   {'symbol': 'MFT-USDT',
#    'name': 'MFT-USDT',
#    'baseCurrency': 'MFT',
#    'quoteCurrency': 'USDT',
#    'feeCurrency': 'USDT',
#    'market': 'USDS',
#    'baseMinSize': '10',
#    'quoteMinSize': '0.001',
#    'baseMaxSize': '10000000000',
#    'quoteMaxSize': '99999999',
#    'baseIncrement': '0.0001',
#    'quoteIncrement': '0.00001',
#    'priceIncrement': '0.00001',
#    'priceLimitRate': '0.1',
#    'isMarginEnabled': False,
#    'enableTrading': True},
#   ...]}

# %% [markdown]
# # Get ticker

# %%
endpoint = "/api/v1/market/orderbook/level1"
param = {
    "symbol": "BTC-USDT"
}
ticker = getPublic(endpoint, param)

# %%
ticker
# Out:
# {'code': '200000',
#  'data': {'time': 1643971988410,
#   'sequence': '1625592306100',
#   'price': '37921',
#   'size': '0.0018013',
#   'bestBid': '37921',
#   'bestBidSize': '1.09518685',
#   'bestAsk': '37921.1',
#   'bestAskSize': '0.30796'}}

# %% [markdown]
# ## Get 24 hours stats

# %%
endpoint = "/api/v1/market/stats"
param = {
    "symbol": "BTC-USDT"
}
stats = getPublic(endpoint, param)

# %%
stats
# Out:
# {'code': '200000',
#  'data': {'time': 1643972204005,
#   'symbol': 'BTC-USDT',
#   'buy': '37907.1',
#   'sell': '37907.2',
#   'changeRate': '0.0412',
#   'changePrice': '1502.5',
#   'high': '38230.6',
#   'low': '36249.1',
#   'vol': '8139.36690482',
#   'volValue': '302037347.911416206',
#   'last': '37912.8',
#   'averagePrice': '36933.49236406',
#   'takerFeeRate': '0.001',
#   'makerFeeRate': '0.001',
#   'takerCoefficient': '1',
#   'makerCoefficient': '1'}}

# %% [markdown]
# ## Get orderbook

# %%
endpoint = "/api/v1/market/orderbook/level2_20"
param = {
    "symbol": "BTC-USDT"
}
orderbook = getPublic(endpoint, param)

# %%
orderbook
# Out:
# {'code': '200000',
#  'data': {'time': 1643972147269,
#   'sequence': '1625592349926',
#   'bids': [['37907.1', '0.03059503'],
#    ['37906.4', '0.00094378'],
#    ['37904.4', '0.11'],
#    ['37904.3', '0.07'],
#    ['37904.2', '1.7'],
#    ['37903.5', '0.001'],
#    ['37903.3', '0.72525899'],
#    ['37902.5', '0.04328711'],
#    ['37902.4', '0.0061254'],
#    ['37902.1', '0.09'],
#    ['37900.7', '0.13192252'],
#    ['37900', '0.01590653'],
#    ['37899.4', '0.50044'],
#    ['37899', '0.65947747'],
#    ['37898.8', '0.13192252'],
#    ['37894.7', '0.00966'],
#    ['37893.7', '0.0001'],
#    ['37893.6', '0.79180743'],
#    ['37891.2', '0.00059023'],
#    ['37891', '0.00017557']],
#   'asks': [['37907.2', '1.2287971'],
#    ['37908.7', '0.001'],
#    ['37908.8', '0.003'],
#    ['37908.9', '0.03'],
#    ['37909.2', '0.02'],
#    ['37909.3', '0.50044'],
#    ['37910.1', '0.07106418'],
#    ['37910.3', '0.003'],
#    ['37910.5', '0.18679906'],
#    ['37912.4', '0.18680245'],
#    ['37912.5', '1.7'],
#    ['37912.6', '0.355'],
#    ['37912.7', '0.05488'],
#    ['37913.6', '0.05519116'],
#    ['37918.4', '0.16'],
#    ['37920.5', '0.081'],
#    ['37921.5', '0.20655785'],
#    ['37921.8', '0.0005'],
#    ['37922.5', '0.05509415'],
#    ['37923.7', '0.32']]}}

# %% [markdown]
# # Get trade history

# %%
endpoint = "/api/v1/market/histories"
param = {
    "symbol": "BTC-USDT"
}
trades = getPublic(endpoint, param)

# %%
trades
# Out:
# {'code': '200000',
#  'data': [{'sequence': '1625594770448',
#    'price': '37858.1',
#    'size': '0.0001294',
#    'side': 'sell',
#    'time': 1643981088902209426},
#   {'sequence': '1625594770793',
#    'price': '37858.6',
#    'size': '0.00038992',
#    'side': 'sell',
#    'time': 1643981089047370918},
#   {'sequence': '1625594771082',
#    'price': '37861.2',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981089418509701},
#   {'sequence': '1625594771285',
#    'price': '37861.1',
#    'size': '0.00001',
#    'side': 'sell',
#    'time': 1643981090017627601},
#   {'sequence': '1625594771388',
#    'price': '37861.2',
#    'size': '0.01032861',
#    'side': 'buy',
#    'time': 1643981090458590226},
#   {'sequence': '1625594771722',
#    'price': '37861.2',
#    'size': '0.00377585',
#    'side': 'buy',
#    'time': 1643981091941566310},
#   {'sequence': '1625594771881',
#    'price': '37861.1',
#    'size': '0.01776711',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771883',
#    'price': '37861.1',
#    'size': '0.12694182',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771885',
#    'price': '37861.1',
#    'size': '0.08374428',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771887',
#    'price': '37861.1',
#    'size': '0.05537604',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771889',
#    'price': '37861.1',
#    'size': '0.08969429',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771891',
#    'price': '37861.1',
#    'size': '0.00119797',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771893',
#    'price': '37861.1',
#    'size': '0.01701209',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771895',
#    'price': '37861.1',
#    'size': '0.05',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771897',
#    'price': '37861.1',
#    'size': '0.01701209',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594771899',
#    'price': '37861.1',
#    'size': '0.02',
#    'side': 'sell',
#    'time': 1643981092400327187},
#   {'sequence': '1625594772151',
#    'price': '37857.3',
#    'size': '0.00138',
#    'side': 'sell',
#    'time': 1643981092548826733},
#   {'sequence': '1625594772154',
#    'price': '37857.3',
#    'size': '0.00138',
#    'side': 'sell',
#    'time': 1643981092548941315},
#   {'sequence': '1625594772161',
#    'price': '37857.3',
#    'size': '0.00138',
#    'side': 'sell',
#    'time': 1643981092549116675},
#   {'sequence': '1625594772166',
#    'price': '37857.3',
#    'size': '0.00138',
#    'side': 'sell',
#    'time': 1643981092549214200},
#   {'sequence': '1625594772372',
#    'price': '37857.2',
#    'size': '0.001',
#    'side': 'sell',
#    'time': 1643981092697308108},
#   {'sequence': '1625594772374',
#    'price': '37856.5',
#    'size': '0.00138',
#    'side': 'sell',
#    'time': 1643981092697308108},
#   {'sequence': '1625594772377',
#    'price': '37856.5',
#    'size': '0.00000858',
#    'side': 'sell',
#    'time': 1643981092697447890},
#   {'sequence': '1625594772608',
#    'price': '37854.5',
#    'size': '0.01848488',
#    'side': 'buy',
#    'time': 1643981093054898702},
#   {'sequence': '1625594772611',
#    'price': '37854.5',
#    'size': '0.01846973',
#    'side': 'buy',
#    'time': 1643981093055152929},
#   {'sequence': '1625594773171',
#    'price': '37850.2',
#    'size': '0.11537212',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773173',
#    'price': '37850.2',
#    'size': '0.01777258',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773175',
#    'price': '37850.2',
#    'size': '0.05095394',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773177',
#    'price': '37850.2',
#    'size': '0.05937048',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773179',
#    'price': '37850.2',
#    'size': '0.08994569',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773181',
#    'price': '37850.2',
#    'size': '0.00120135',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773183',
#    'price': '37850.2',
#    'size': '0.01701209',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773185',
#    'price': '37850.2',
#    'size': '0.02253209',
#    'side': 'buy',
#    'time': 1643981093526218219},
#   {'sequence': '1625594773224',
#    'price': '37851',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981093568333038},
#   {'sequence': '1625594773480',
#    'price': '37852.4',
#    'size': '0.00240407',
#    'side': 'buy',
#    'time': 1643981093809422939},
#   {'sequence': '1625594773530',
#    'price': '37852.4',
#    'size': '0.00001625',
#    'side': 'buy',
#    'time': 1643981093915331276},
#   {'sequence': '1625594773583',
#    'price': '37852.4',
#    'size': '0.11987832',
#    'side': 'buy',
#    'time': 1643981094273808243},
#   {'sequence': '1625594773600',
#    'price': '37852.4',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981094284342671},
#   {'sequence': '1625594773605',
#    'price': '37853.6',
#    'size': '0.00002639',
#    'side': 'buy',
#    'time': 1643981094284502245},
#   {'sequence': '1625594773646',
#    'price': '37853.6',
#    'size': '0.00297361',
#    'side': 'buy',
#    'time': 1643981094306414650},
#   {'sequence': '1625594773650',
#    'price': '37853.7',
#    'size': '0.02399593',
#    'side': 'buy',
#    'time': 1643981094306520457},
#   {'sequence': '1625594773652',
#    'price': '37854',
#    'size': '0.1968761',
#    'side': 'buy',
#    'time': 1643981094306520457},
#   {'sequence': '1625594773680',
#    'price': '37854',
#    'size': '0.00878836',
#    'side': 'buy',
#    'time': 1643981094316427012},
#   {'sequence': '1625594773736',
#    'price': '37855',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981094359633295},
#   {'sequence': '1625594774693',
#    'price': '37857.5',
#    'size': '0.0000365',
#    'side': 'sell',
#    'time': 1643981095250275696},
#   {'sequence': '1625594774704',
#    'price': '37857.6',
#    'size': '0.00001884',
#    'side': 'buy',
#    'time': 1643981095260890960},
#   {'sequence': '1625594774973',
#    'price': '37858.1',
#    'size': '0.0000164',
#    'side': 'buy',
#    'time': 1643981095672618841},
#   {'sequence': '1625594774976',
#    'price': '37858.1',
#    'size': '0.00001654',
#    'side': 'buy',
#    'time': 1643981095672878434},
#   {'sequence': '1625594775375',
#    'price': '37858.7',
#    'size': '0.00001596',
#    'side': 'buy',
#    'time': 1643981096769292072},
#   {'sequence': '1625594775491',
#    'price': '37858.7',
#    'size': '0.00001622',
#    'side': 'buy',
#    'time': 1643981096956908363},
#   {'sequence': '1625594775499',
#    'price': '37858.7',
#    'size': '0.00003026',
#    'side': 'buy',
#    'time': 1643981096966563017},
#   {'sequence': '1625594775669',
#    'price': '37858.7',
#    'size': '0.00027108',
#    'side': 'buy',
#    'time': 1643981097518874536},
#   {'sequence': '1625594775876',
#    'price': '37858.7',
#    'size': '0.00002639',
#    'side': 'buy',
#    'time': 1643981098296548635},
#   {'sequence': '1625594776035',
#    'price': '37858.6',
#    'size': '0.00820631',
#    'side': 'sell',
#    'time': 1643981099072920609},
#   {'sequence': '1625594776073',
#    'price': '37858.6',
#    'size': '0.00027108',
#    'side': 'sell',
#    'time': 1643981099281219698},
#   {'sequence': '1625594776119',
#    'price': '37858.6',
#    'size': '0.1145957',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776121',
#    'price': '37858.6',
#    'size': '0.0177756',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776123',
#    'price': '37858.6',
#    'size': '0.06281968',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776125',
#    'price': '37858.6',
#    'size': '0.05390201',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776127',
#    'price': '37858.6',
#    'size': '0.08977809',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776129',
#    'price': '37858.6',
#    'size': '0.0011991',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776131',
#    'price': '37858.6',
#    'size': '0.01701209',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776133',
#    'price': '37858.6',
#    'size': '0.02209191',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776135',
#    'price': '37858.6',
#    'size': '0.02209191',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776137',
#    'price': '37858.6',
#    'size': '0.01701209',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776139',
#    'price': '37858.6',
#    'size': '0.001',
#    'side': 'sell',
#    'time': 1643981099386750514},
#   {'sequence': '1625594776297',
#    'price': '37855.3',
#    'size': '0.003',
#    'side': 'sell',
#    'time': 1643981099451589330},
#   {'sequence': '1625594776508',
#    'price': '37853.6',
#    'size': '0.00007429',
#    'side': 'sell',
#    'time': 1643981099517107820},
#   {'sequence': '1625594776510',
#    'price': '37851.4',
#    'size': '0.00293571',
#    'side': 'sell',
#    'time': 1643981099517107820},
#   {'sequence': '1625594776521',
#    'price': '37851.4',
#    'size': '0.00026429',
#    'side': 'sell',
#    'time': 1643981099517423677},
#   {'sequence': '1625594776523',
#    'price': '37851',
#    'size': '0.00001',
#    'side': 'sell',
#    'time': 1643981099517423677},
#   {'sequence': '1625594777101',
#    'price': '37850.1',
#    'size': '0.0073012',
#    'side': 'sell',
#    'time': 1643981100567373739},
#   {'sequence': '1625594777427',
#    'price': '37850.2',
#    'size': '0.0002706',
#    'side': 'buy',
#    'time': 1643981101761128690},
#   {'sequence': '1625594777491',
#    'price': '37850.2',
#    'size': '0.01750298',
#    'side': 'buy',
#    'time': 1643981101857243534},
#   {'sequence': '1625594777493',
#    'price': '37850.2',
#    'size': '0.11795128',
#    'side': 'buy',
#    'time': 1643981101857243534},
#   {'sequence': '1625594777495',
#    'price': '37850.2',
#    'size': '0.0010119',
#    'side': 'buy',
#    'time': 1643981101857243534},
#   {'sequence': '1625594777498',
#    'price': '37850.2',
#    'size': '0.05092473',
#    'side': 'buy',
#    'time': 1643981101857578360},
#   {'sequence': '1625594777500',
#    'price': '37850.2',
#    'size': '0.08988982',
#    'side': 'buy',
#    'time': 1643981101857578360},
#   {'sequence': '1625594777502',
#    'price': '37850.2',
#    'size': '0.01465463',
#    'side': 'buy',
#    'time': 1643981101857578360},
#   {'sequence': '1625594777523',
#    'price': '37850.1',
#    'size': '0.00004392',
#    'side': 'sell',
#    'time': 1643981101877695828},
#   {'sequence': '1625594777566',
#    'price': '37850.2',
#    'size': '0.04586558',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777568',
#    'price': '37850.2',
#    'size': '0.01701209',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777570',
#    'price': '37850.2',
#    'size': '0.27048',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777572',
#    'price': '37850.2',
#    'size': '0.0012006',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777574',
#    'price': '37850.2',
#    'size': '0.01701209',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777576',
#    'price': '37850.2',
#    'size': '0.0073012',
#    'side': 'buy',
#    'time': 1643981101930878552},
#   {'sequence': '1625594777623',
#    'price': '37850.2',
#    'size': '0.00004392',
#    'side': 'buy',
#    'time': 1643981101972472531},
#   {'sequence': '1625594777650',
#    'price': '37851',
#    'size': '0.00013236',
#    'side': 'sell',
#    'time': 1643981101973238914},
#   {'sequence': '1625594778136',
#    'price': '37857.7',
#    'size': '0.0021',
#    'side': 'buy',
#    'time': 1643981102152783628},
#   {'sequence': '1625594778190',
#    'price': '37857.7',
#    'size': '0.0011',
#    'side': 'buy',
#    'time': 1643981102174875055},
#   {'sequence': '1625594778192',
#    'price': '37858.5',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981102174875055},
#   {'sequence': '1625594778201',
#    'price': '37858.5',
#    'size': '0.0021',
#    'side': 'buy',
#    'time': 1643981102185095875},
#   {'sequence': '1625594778206',
#    'price': '37858.5',
#    'size': '0.0021',
#    'side': 'buy',
#    'time': 1643981102185334606},
#   {'sequence': '1625594778564',
#    'price': '37858.6',
#    'size': '0.00010471',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778566',
#    'price': '37859.6',
#    'size': '0.001',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778568',
#    'price': '37859.6',
#    'size': '0.0032',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778570',
#    'price': '37859.9',
#    'size': '0.0005',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778572',
#    'price': '37860.4',
#    'size': '0.02',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778574',
#    'price': '37860.9',
#    'size': '0.00067336',
#    'side': 'buy',
#    'time': 1643981102480784224},
#   {'sequence': '1625594778699',
#    'price': '37859.4',
#    'size': '0.0001674',
#    'side': 'sell',
#    'time': 1643981102555141756}]}

# %% [markdown]
# # Get klines

# %%
etime = int(time.time())
stime = etime - 3600 * 24
endpoint = "/api/v1/market/candles"
param = {
    "type": "1hour",
    "symbol": "BTC-USDT",
    "startAt": stime,
    "endAt": etime
}
klines = getPublic(endpoint, param)

# %%
klines
# Out:
# {'code': '200000',
#  'data': [['1643979600',
#    '37958.3',
#    '37599.6',
#    '38191.9',
#    '37531.8',
#    '427.77243625',
#    '16170109.319390346'],
#   ['1643976000',
#    '37807.6',
#    '37958.2',
#    '38055.9',
#    '37807.5',
#    '169.60274441',
#    '6434772.064830966'],
#   ['1643972400',
#    '37879.2',
#    '37809.1',
#    '37971',
#    '37803',
#    '220.90606105',
#    '8368904.465767326'],
#   ['1643968800',
#    '38017.8',
#    '37884.4',
#    '38230.6',
#    '37773.2',
#    '375.26458349',
#    '14252307.849597419'],
#   ['1643965200',
#    '37964.4',
#    '38017.8',
#    '38119.9',
#    '37902',
#    '229.76468911',
#    '8729389.759929234'],
#   ['1643961600',
#    '37864.4',
#    '37964.4',
#    '38042.5',
#    '37849.5',
#    '372.41793183',
#    '14130132.355849635'],
#   ['1643958000',
#    '37988.8',
#    '37864.4',
#    '38208.5',
#    '37838.4',
#    '357.30448883',
#    '13566909.735229762'],
#   ['1643954400',
#    '37543.3',
#    '37985.2',
#    '38028.5',
#    '37543.3',
#    '508.66820201',
#    '19253232.824365059'],
#   ['1643950800',
#    '37302.4',
#    '37543.2',
#    '37693.6',
#    '37268.6',
#    '500.09841129',
#    '18772587.021733694'],
#   ['1643947200',
#    '37307.7',
#    '37302.3',
#    '37360.7',
#    '37254',
#    '136.88471395',
#    '5105689.023466222'],
#   ['1643943600',
#    '37334',
#    '37307.6',
#    '37421.3',
#    '37266.3',
#    '170.23088228',
#    '6357985.633210673'],
#   ['1643940000',
#    '37175.6',
#    '37333.9',
#    '37447',
#    '37149',
#    '263.54006335',
#    '9836186.538204144'],
#   ['1643936400',
#    '37192.3',
#    '37175.5',
#    '37449.5',
#    '37032',
#    '237.72032982',
#    '8829742.181707321'],
#   ['1643932800',
#    '37320.9',
#    '37192.3',
#    '37331.1',
#    '37122.5',
#    '261.22348319',
#    '9722065.323373252'],
#   ['1643929200',
#    '36935.4',
#    '37320.9',
#    '37381.9',
#    '36792',
#    '409.82245576',
#    '15184484.217057945'],
#   ['1643925600',
#    '36951.7',
#    '36935.4',
#    '37009.1',
#    '36800',
#    '165.47174381',
#    '6106193.797665749'],
#   ['1643922000',
#    '36366.8',
#    '36950.4',
#    '37049.9',
#    '36357.1',
#    '567.99623362',
#    '20913260.383194139'],
#   ['1643918400',
#    '36555.1',
#    '36366.7',
#    '36640',
#    '36270',
#    '340.02129667',
#    '12395324.532481922'],
#   ['1643914800',
#    '36764.7',
#    '36555.2',
#    '36824.9',
#    '36451.2',
#    '305.00829808',
#    '11160473.250024492'],
#   ['1643911200',
#    '36825.9',
#    '36764.6',
#    '36849.8',
#    '36652.3',
#    '307.54249755',
#    '11304085.952327908'],
#   ['1643907600',
#    '36699.7',
#    '36825.9',
#    '36883',
#    '36563',
#    '372.12034521',
#    '13667403.589353631'],
#   ['1643904000',
#    '36919.9',
#    '36696',
#    '37100',
#    '36696',
#    '310.39268307',
#    '11453730.956497504'],
#   ['1643900400',
#    '36506',
#    '36919.9',
#    '36977.4',
#    '36474.1',
#    '411.21518096',
#    '15118461.313087849'],
#   ['1643896800',
#    '36585.4',
#    '36512.2',
#    '36767.2',
#    '36486',
#    '340.46962101',
#    '12468010.143695003']]}
